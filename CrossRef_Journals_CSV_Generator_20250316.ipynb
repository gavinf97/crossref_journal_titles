# %%
# Google Colab notebook to download all 150k approx journal titles usable for DOME Wizard template to reduce free text
import requests
import csv
import time

def get_total_journal_count():
    """
    Get the total number of journals available in Crossref

    Returns:
    Integer representing total journal count
    """
    base_url = "https://api.crossref.org/journals"
    headers = {
        "User-Agent": "JournalExporter/1.0 (mailto:your-email@example.com)"
    }

    params = {
        "rows": 0  # We only need the metadata, not actual results
    }

    response = requests.get(base_url, params=params, headers=headers)

    if response.status_code != 200:
        print(f"Error: API responded with status code {response.status_code}")
        return None

    data = response.json()
    total_results = data.get('message', {}).get('total-results', 0)

    return total_results

def get_all_journals(rows_per_request=1000, max_requests=None):
    """
    Retrieve journal titles from Crossref API and return them as a list

    Parameters:
    rows_per_request: Number of journals to retrieve per API call
    max_requests: Maximum number of API requests to make (None for all journals)

    Returns:
    List of dictionaries containing journal information
    """
    journals = []
    cursor = "*"  # Starting cursor for pagination
    base_url = "https://api.crossref.org/journals"

    # Set up headers with user agent as recommended by Crossref
    headers = {
        "User-Agent": "JournalExporter/1.0 (mailto:your-email@example.com)"
    }

    # Get total number of journals
    total_journals = get_total_journal_count()
    if total_journals is None:
        print("Could not determine total journal count. Using default max_requests.")
    else:
        print(f"Total journals available: {total_journals}")
        if max_requests is None:
            # Calculate required requests to get all journals
            max_requests = (total_journals // rows_per_request) + 1
            print(f"Will need approximately {max_requests} requests to retrieve all journals")

    # Default to 100 if max_requests is still None
    if max_requests is None:
        max_requests = 100
        print(f"Using default maximum of {max_requests} requests")

    request_count = 0
    while request_count < max_requests:
        params = {
            "rows": rows_per_request,
            "cursor": cursor
        }

        print(f"Making request {request_count+1}/{max_requests}...")
        response = requests.get(base_url, params=params, headers=headers)

        if response.status_code != 200:
            print(f"Error: API responded with status code {response.status_code}")
            break

        data = response.json()

        # Extract the items and add to our list
        items = data.get('message', {}).get('items', [])
        if not items:
            print("No more journals to retrieve.")
            break

        journals.extend(items)

        # Get next cursor for pagination
        next_cursor = data.get('message', {}).get('next-cursor')
        if not next_cursor:
            print("No next cursor available. Finished retrieving journals.")
            break

        cursor = next_cursor
        request_count += 1

        # Progress report
        print(f"Retrieved {len(journals)} journals so far ({len(journals)/total_journals*100:.2f}% complete)...")

        # Sleep to be nice to the API
        time.sleep(1)

    return journals

def save_journals_to_csv(journals, filename="crossref_journals.csv"):
    """
    Save journal data to a CSV file

    Parameters:
    journals: List of journal dictionaries from Crossref API
    filename: Name of the output CSV file
    """
    # Define which fields to extract from each journal
    fieldnames = ["title", "issn", "publisher"]

    with open(filename, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for journal in journals:
            # Extract the required fields from each journal
            row = {
                "title": journal.get("title", ""),
                "issn": ", ".join(journal.get("issn", [])),
                "publisher": journal.get("publisher", "")
            }
            writer.writerow(row)

    print(f"Successfully saved {len(journals)} journal titles to {filename}")

def main():
    print("Checking total number of journals in Crossref...")
    total_count = get_total_journal_count()
    if total_count:
        print(f"Found {total_count} total journals available in Crossref")

    retrieve_all = input("Retrieve all journals? (y/n, default: n): ").lower() == 'y'

    if retrieve_all:
        print("Starting to retrieve ALL journals from Crossref API...")
        journals = get_all_journals(max_requests=None)  # None means get all
    else:
        max_requests = int(input("Enter maximum number of requests (1000 journals per request): ") or "100")
        print(f"Starting to retrieve journals from Crossref API (max {max_requests} requests)...")
        journals = get_all_journals(max_requests=max_requests)

    if not journals:
        print("No journals retrieved. Exiting.")
        return

    print(f"Retrieved {len(journals)} journals. Saving to CSV...")
    save_journals_to_csv(journals)
    print("Done!")

if __name__ == "__main__":
    main()
# Out:
# Checking total number of journals in Crossref...
# Found 145416 total journals available in Crossref
# Retrieve all journals? (y/n, default: n): y
# Starting to retrieve ALL journals from Crossref API...
# Total journals available: 145416
# Will need approximately 146 requests to retrieve all journals
# Making request 1/146...
# Retrieved 1000 journals so far (0.69% complete)...
# Making request 2/146...
# Retrieved 2000 journals so far (1.38% complete)...
# Making request 3/146...
# Retrieved 3000 journals so far (2.06% complete)...
# Making request 4/146...
# Retrieved 4000 journals so far (2.75% complete)...
# Making request 5/146...
# Retrieved 5000 journals so far (3.44% complete)...
# Making request 6/146...
# Retrieved 6000 journals so far (4.13% complete)...
# Making request 7/146...
# Retrieved 7000 journals so far (4.81% complete)...
# Making request 8/146...
# Retrieved 8000 journals so far (5.50% complete)...
# Making request 9/146...
# Retrieved 9000 journals so far (6.19% complete)...
# Making request 10/146...
# Retrieved 10000 journals so far (6.88% complete)...
# Making request 11/146...
# Retrieved 11000 journals so far (7.56% complete)...
# Making request 12/146...
# Retrieved 12000 journals so far (8.25% complete)...
# Making request 13/146...
# Retrieved 13000 journals so far (8.94% complete)...
# Making request 14/146...
# Retrieved 14000 journals so far (9.63% complete)...
# Making request 15/146...
# Retrieved 15000 journals so far (10.32% complete)...
# Making request 16/146...
# Retrieved 16000 journals so far (11.00% complete)...
# Making request 17/146...
# Retrieved 17000 journals so far (11.69% complete)...
# Making request 18/146...
# Retrieved 18000 journals so far (12.38% complete)...
# Making request 19/146...
# Retrieved 19000 journals so far (13.07% complete)...
# Making request 20/146...
# Retrieved 20000 journals so far (13.75% complete)...
# Making request 21/146...
# Retrieved 21000 journals so far (14.44% complete)...
# Making request 22/146...
# Retrieved 22000 journals so far (15.13% complete)...
# Making request 23/146...
# Retrieved 23000 journals so far (15.82% complete)...
# Making request 24/146...
# Retrieved 24000 journals so far (16.50% complete)...
# Making request 25/146...
# Retrieved 25000 journals so far (17.19% complete)...
# Making request 26/146...
# Retrieved 26000 journals so far (17.88% complete)...
# Making request 27/146...
# Retrieved 27000 journals so far (18.57% complete)...
# Making request 28/146...
# Retrieved 28000 journals so far (19.26% complete)...
# Making request 29/146...
# Retrieved 29000 journals so far (19.94% complete)...
# Making request 30/146...
# Retrieved 30000 journals so far (20.63% complete)...
# Making request 31/146...
# Retrieved 31000 journals so far (21.32% complete)...
# Making request 32/146...
# Retrieved 32000 journals so far (22.01% complete)...
# Making request 33/146...
# Retrieved 33000 journals so far (22.69% complete)...
# Making request 34/146...
# Retrieved 34000 journals so far (23.38% complete)...
# Making request 35/146...
# Retrieved 35000 journals so far (24.07% complete)...
# Making request 36/146...
# Retrieved 36000 journals so far (24.76% complete)...
# Making request 37/146...
# Retrieved 37000 journals so far (25.44% complete)...
# Making request 38/146...
# Retrieved 38000 journals so far (26.13% complete)...
# Making request 39/146...
# Retrieved 39000 journals so far (26.82% complete)...
# Making request 40/146...
# Retrieved 40000 journals so far (27.51% complete)...
# Making request 41/146...
# Retrieved 41000 journals so far (28.19% complete)...
# Making request 42/146...
# Retrieved 42000 journals so far (28.88% complete)...
# Making request 43/146...
# Retrieved 43000 journals so far (29.57% complete)...
# Making request 44/146...
# Retrieved 44000 journals so far (30.26% complete)...
# Making request 45/146...
# Retrieved 45000 journals so far (30.95% complete)...
# Making request 46/146...
# Retrieved 46000 journals so far (31.63% complete)...
# Making request 47/146...
# Retrieved 47000 journals so far (32.32% complete)...
# Making request 48/146...
# Retrieved 48000 journals so far (33.01% complete)...
# Making request 49/146...
# Retrieved 49000 journals so far (33.70% complete)...
# Making request 50/146...
# Retrieved 50000 journals so far (34.38% complete)...
# Making request 51/146...
# Retrieved 51000 journals so far (35.07% complete)...
# Making request 52/146...
# Retrieved 52000 journals so far (35.76% complete)...
# Making request 53/146...
# Retrieved 53000 journals so far (36.45% complete)...
# Making request 54/146...
# Retrieved 54000 journals so far (37.13% complete)...
# Making request 55/146...
# Retrieved 55000 journals so far (37.82% complete)...
# Making request 56/146...
# Retrieved 56000 journals so far (38.51% complete)...
# Making request 57/146...
# Retrieved 57000 journals so far (39.20% complete)...
# Making request 58/146...
# Retrieved 58000 journals so far (39.89% complete)...
# Making request 59/146...
# Retrieved 59000 journals so far (40.57% complete)...
# Making request 60/146...
# Retrieved 60000 journals so far (41.26% complete)...
# Making request 61/146...
# Retrieved 61000 journals so far (41.95% complete)...
# Making request 62/146...
# Retrieved 62000 journals so far (42.64% complete)...
# Making request 63/146...
# Retrieved 63000 journals so far (43.32% complete)...
# Making request 64/146...
# Retrieved 64000 journals so far (44.01% complete)...
# Making request 65/146...
# Retrieved 65000 journals so far (44.70% complete)...
# Making request 66/146...
# Retrieved 66000 journals so far (45.39% complete)...
# Making request 67/146...
# Retrieved 67000 journals so far (46.07% complete)...
# Making request 68/146...
# Retrieved 68000 journals so far (46.76% complete)...
# Making request 69/146...
# Retrieved 69000 journals so far (47.45% complete)...
# Making request 70/146...
# Retrieved 70000 journals so far (48.14% complete)...
# Making request 71/146...
# Retrieved 71000 journals so far (48.83% complete)...
# Making request 72/146...
# Retrieved 72000 journals so far (49.51% complete)...
# Making request 73/146...
# Retrieved 73000 journals so far (50.20% complete)...
# Making request 74/146...
# Retrieved 74000 journals so far (50.89% complete)...
# Making request 75/146...
# Retrieved 75000 journals so far (51.58% complete)...
# Making request 76/146...
# Retrieved 76000 journals so far (52.26% complete)...
# Making request 77/146...
# Retrieved 77000 journals so far (52.95% complete)...
# Making request 78/146...
# Retrieved 78000 journals so far (53.64% complete)...
# Making request 79/146...
# Retrieved 79000 journals so far (54.33% complete)...
# Making request 80/146...
# Retrieved 80000 journals so far (55.01% complete)...
# Making request 81/146...
# Retrieved 81000 journals so far (55.70% complete)...
# Making request 82/146...
# Retrieved 82000 journals so far (56.39% complete)...
# Making request 83/146...
# Retrieved 83000 journals so far (57.08% complete)...
# Making request 84/146...
# Retrieved 84000 journals so far (57.77% complete)...
# Making request 85/146...
# Retrieved 85000 journals so far (58.45% complete)...
# Making request 86/146...
# Retrieved 86000 journals so far (59.14% complete)...
# Making request 87/146...
# Retrieved 87000 journals so far (59.83% complete)...
# Making request 88/146...
# Retrieved 88000 journals so far (60.52% complete)...
# Making request 89/146...
# Retrieved 89000 journals so far (61.20% complete)...
# Making request 90/146...
# Retrieved 90000 journals so far (61.89% complete)...
# Making request 91/146...
# Retrieved 91000 journals so far (62.58% complete)...
# Making request 92/146...
# Retrieved 92000 journals so far (63.27% complete)...
# Making request 93/146...
# Retrieved 93000 journals so far (63.95% complete)...
# Making request 94/146...
# Retrieved 94000 journals so far (64.64% complete)...
# Making request 95/146...
# Retrieved 95000 journals so far (65.33% complete)...
# Making request 96/146...
# Retrieved 96000 journals so far (66.02% complete)...
# Making request 97/146...
